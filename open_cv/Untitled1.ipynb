# %%
pip install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      |████████████████████████████████| 59 kB 29 kB/s eta 0:00:01
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting PyTweening>=1.0.1
#   Downloading PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Collecting python3-Xlib
#   Downloading python3-xlib-0.15.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 71 kB/s eta 0:00:01
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Requirement already satisfied: Pillow>=6.2.1 in ./anaconda3/lib/python3.8/site-packages (from pyscreeze>=0.1.21->pyautogui) (8.2.0)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect, python3-Xlib
#   Building wheel for pyautogui (setup.py) ... done
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36583 sha256=70df73dafbf2c42669994b99ea0edb8e721523dfdad9f5a4ebb61cc7ee8104b6
#   Stored in directory: /home/garvit/.cache/pip/wheels/54/04/f7/55704a9d374ed923785a4fdc0ef00151fa25306b3b93345532
#   Building wheel for pygetwindow (setup.py) ... done
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11078 sha256=9f4619ffff7527803bbc55cf6defabc83f088a42b2b85239fa85094ac6edc3b6
#   Stored in directory: /home/garvit/.cache/pip/wheels/91/e3/04/184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for pyscreeze (PEP 517) ... done
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-py3-none-any.whl size=12891 sha256=ab002852fc960ebd6d3914371fbd3007e110ade86cba7a15e426f8041584f40c
#   Stored in directory: /home/garvit/.cache/pip/wheels/f7/91/eb/c0fa176c095c77460a579ef339f24a377474b041e5543d1a00
#   Building wheel for PyTweening (setup.py) ... done
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3815 sha256=e8d3d52b09201dc2e25904976834a281f801ad365e74b0568720ed2d21a6ccb1
#   Stored in directory: /home/garvit/.cache/pip/wheels/e7/50/20/790fbd95739abfdf0348bef99d5cc0c7c2930a19a91f602ddc
#   Building wheel for mouseinfo (setup.py) ... done
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10905 sha256=22aabad8d7ddb7fcf6a66c66ceb1753c45025233d0c39baf82ac298f346007f5
#   Stored in directory: /home/garvit/.cache/pip/wheels/d1/72/fb/35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pymsgbox (PEP 517) ... done
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=52d3da13364dba9bc1fac8043f487aae43cda00a5ba9c9aef47a8ed41a027c51
#   Stored in directory: /home/garvit/.cache/pip/wheels/91/28/0d/f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11107 sha256=e0859845d066336b96d49715d9ec3ceaa766861bc029b61332217a146d46dc87
#   Stored in directory: /home/garvit/.cache/pip/wheels/7f/1a/65/84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
#   Building wheel for pyrect (setup.py) ... done
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9547 sha256=c40c9ff1316b6e6301e6e685b6640e1465dd3df4b1f0c887c179178b6ab1d2bc
#   Stored in directory: /home/garvit/.cache/pip/wheels/d1/e4/47/c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
#   Building wheel for python3-Xlib (setup.py) ... done
#   Created wheel for python3-Xlib: filename=python3_xlib-0.15-py3-none-any.whl size=109516 sha256=1c7b9fafd9cef631692e263edc865cbc26021770b870904898ac26c1cffbe5ac
#   Stored in directory: /home/garvit/.cache/pip/wheels/46/4e/a7/90774eeed70e4e93598bf4cbb1ef00c56e6bdc0fb99cc4215d
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect python3-Xlib
# Installing collected packages: python3-Xlib, pyrect, pyperclip, PyTweening, pyscreeze, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.3 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.27 python3-Xlib-0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import cv2
import time

# %%
import pyautogui

# %%
webcam = cv2.VideoCapture(0)

# %%
while(1):
      

    _, imageFrame = webcam.read()
  

    hsvFrame = cv2.cvtColor(imageFrame, cv2.COLOR_BGR2HSV)
  
   
    red_lower = np.array([170, 120, 70], np.uint8)
    red_upper = np.array([180, 255, 255], np.uint8)
    red_mask = cv2.inRange(hsvFrame, red_lower, red_upper)
    
    green_lower = np.array([25, 52, 72], np.uint8)
    green_upper = np.array([86, 255, 255], np.uint8)
    green_mask = cv2.inRange(hsvFrame, green_lower, green_upper)
  
    
    blue_lower = np.array([100, 100, 100], np.uint8)
    blue_upper = np.array([140, 200, 240], np.uint8)
    blue_mask = cv2.inRange(hsvFrame, blue_lower, blue_upper)
      
    
    kernal = np.ones((5, 5), "uint8")
      
 
    red_mask = cv2.dilate(red_mask, kernal)
    res_red = cv2.bitwise_and(imageFrame, imageFrame, 
                              mask = red_mask)
      
    
    green_mask = cv2.dilate(green_mask, kernal)
    res_green = cv2.bitwise_and(imageFrame, imageFrame,
                                mask = green_mask)
    blue_mask = cv2.dilate(blue_mask, kernal)
    res_blue = cv2.bitwise_and(imageFrame, imageFrame,
                               mask = blue_mask)
   
    
    contours, hierarchy = cv2.findContours(red_mask,
                                           cv2.RETR_TREE,
                                           cv2.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv2.contourArea(contour)
        if(area > 300):
             pyautogui.hotkey('ctrl', 'n')
             time.sleep(5)   
            #x, y, w, h = cv2.boundingRect(contour)
            #imageFrame = cv2.rectangle(imageFrame, (x, y), 
                                       #(x + w, y + h), 
                                       #(0, 0, 255), 2)
              
            #cv2.putText(imageFrame, "Red Colour", (x, y),
                        #cv2.FONT_HERSHEY_SIMPLEX, 1.0,
                        #(0, 0, 255))    
              
    contours, hierarchy = cv2.findContours(green_mask,
                                           cv2.RETR_TREE,
                                           cv2.CHAIN_APPROX_SIMPLE)
      
    for pic, contour in enumerate(contours):
        area = cv2.contourArea(contour)
        if(area > 300):
            pyautogui.hotkey('ctrl', 'n')
            time.sleep(5)
            #x, y, w, h = cv2.boundingRect(contour)
            #imageFrame = cv2.rectangle(imageFrame, (x, y), 
                                       #(x + w, y + h),
                                       #(0, 255, 0), 2)
              
            #cv2.putText(imageFrame, "Green Colour", (x, y),
                        #cv2.FONT_HERSHEY_SIMPLEX, 
                        #1.0, (0, 255, 0))
  
    
    contours, hierarchy = cv2.findContours(blue_mask,
                                           cv2.RETR_TREE,
                                           cv2.CHAIN_APPROX_SIMPLE)
    for pic, contour in enumerate(contours):
        area = cv2.contourArea(contour)
        if(area > 300):
            pyautogui.hotkey('ctrl','shift','n')
            time.sleep(5)
            #x, y, w, h = cv2.boundingRect(contour)
            #imageFrame = cv2.rectangle(imageFrame, (x, y),
                                       #(x + w, y + h),
                                       #(255, 0, 0), 2)
              
            #cv2.putText(imageFrame, "Blue Colour", (x, y),
                        #cv2.FONT_HERSHEY_SIMPLEX,
                        #1.0, (255, 0, 0))
              
    
    cv2.imshow("Multiple Color Detection in Real-TIme", imageFrame)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
