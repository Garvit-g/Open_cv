# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('penguin.jpeg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
px=img[50,50]
print(px)
# Out:
# [20 25 29]

# %%
img[50,50,0]=0

# %%
plt.imshow(img)

# %%
img[200:400,200:400,0]=0
img[200:400,200:400,1]=0
img[200:400,200:400,2]=0
plt.imshow(img)
